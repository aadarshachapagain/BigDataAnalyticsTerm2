# %% [markdown]
# # Image Processing

# %% [markdown]
# ## 1.Using OpenCV

# %%
#Importing required Libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30680/612644604.py in <module>
#       1 #Importing required Libraries
#       2 import numpy as np
# ----> 3 import cv2
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
#read Image using imread function
img = cv2.imread("image.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30680/2014506097.py in <module>
#       1 #read Image using imread function
# ----> 2 img = cv2.imread("image.png")
#
# NameError: name 'cv2' is not defined

# %%
#printing type and shape of the array
print(type(img))
print(img.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30680/2536583514.py in <module>
#       1 #printing type and shape of the array
# ----> 2 print(type(img))
#       3 print(img.shape)
#
# NameError: name 'img' is not defined

# %%
#Plottig the result
plt.imshow(img)

# %%
#Convert Image from BRG to RGB using cvtColor function
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
#Image Resize
scale = 20
new_width = int(img_rgb.shape[1] * scale / 100)
new_height = int(img_rgb.shape[0] * scale / 100)
dim = (new_width,new_height)


resized = cv2.resize(img_rgb, dim, interpolation=cv2.INTER_AREA)
plt.imshow(resized)
print(resized.shape)
# Out:
# (230, 172, 3)

# %%
#Cropping the Image
img_crop = img_rgb[550:990, 100:800]
plt.imshow(img_crop)
print(img_crop.shape)
# Out:
# (440, 700, 3)

# %%
#Saving Image
cv2.imwrite('pro_1.png',img)
cv2.imwrite('pro_2.png',resized)
cv2.imwrite('pro_3.png',img_crop)
# Out:
# True

# %% [markdown]
# ## 2.Using Scikit-image

# %%
#Importing Required Libraries
import numpy as np
import skimage
from skimage import io
import matplotlib.pyplot as plt

# %%
#Read Image using imread() function
img_1 = io.imread("prototype.png")

# %%
#Printing type and shape of array
print(type(img_1))
print(img_1.shape)
# Out:
# <class 'numpy.ndarray'>
# (1152, 860, 4)

# %%
#Plotting the result
plt.imshow(img)

# %%
#Resizing the image
from skimage.transform import resize
resized  = resize(img_1, (400,400))
plt.imshow(resized)
print(resized.shape)
# Out:
# (400, 400, 4)

# %%
#Cropping the Image
img_crop = img_rgb[550:990, 100:800]
plt.imshow(img_crop)
print(img_crop.shape)
# Out:
# (440, 700, 3)

# %%
#Saving image using Imsave
io.imsave('pro_4.png',img)
io.imsave('pro_5.png',resized)
io.imsave('pro_6.png',img_crop)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# ##3.Using Pillow

# %%
#Improting Libraries
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
#Read the Image
img_2 = Image.open("prototype.png")

# %%
#Printing the type and the shape of the image
print(type(img_2))
print(img_2.size)
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# (860, 1152)

# %%
#plotting the result
plt.imshow(img_2)

# %%
#Resizing the image
size = (100,100)

resized  = img_2.resize(size)
plt.imshow(resized)
print(resized.size)
# Out:
# (100, 100)

# %%
#Cropping the Image
img_crop = img_2.crop((170,500, 600,900))
plt.imshow(img_crop)
print(img_crop.size)
# Out:
# (430, 400)

# %%
#Saving Image
img_2.save('pr0_7.png')
resized.save('pr0_8.png')
img_crop.save('pr0_9.png')
