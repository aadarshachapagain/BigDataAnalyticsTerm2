# %%
try:
  import databricks.koalas as ks
except:
  import pyspark.pandas as ks

import re
from pyspark.sql import DataFrame as sdf

# %% [markdown]
# # Reading the Data

# %%
# read from the koalas/spark
air_line = ks.read_table("airline_csv")
air_line.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#       <th>review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ham</td>
#       <td>Go until jurong point, crazy.. Available only ...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ham</td>
#       <td>Ok lar... Joking wif u oni...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>spam</td>
#       <td>Free entry in 2 a wkly comp to win FA Cup fina...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ham</td>
#       <td>U dun say so early hor... U c already then say...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ham</td>
#       <td>Nah I don't think he goes to usf, he lives aro...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# read directly into the spark dataframe
spark_df = spark.read.table("airline_csv")
spark_df.show()
# Out:
# +-----+--------------------+
# |label|              review|
# +-----+--------------------+
# |  ham|Go until jurong p...|
# |  ham|Ok lar... Joking ...|
# | spam|Free entry in 2 a...|
# |  ham|U dun say so earl...|
# |  ham|Nah I don't think...|
# | spam|FreeMsg Hey there...|
# |  ham|Even my brother i...|
# |  ham|As per your reque...|
# | spam|WINNER!! As a val...|
# | spam|Had your mobile 1...|
# |  ham|I'm gonna be home...|
# | spam|SIX chances to wi...|
# | spam|URGENT! You have ...|
# |  ham|I've been searchi...|
# |  ham|I HAVE A DATE ON ...|
# | spam|XXXMobileMovieClu...|
# |  ham|Oh k...i'm watchi...|
# |  ham|Eh u remember how...|
# |  ham|Fine if that�s th...|
# | spam|England v Macedon...|
# +-----+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Start Preprocessing with koalas

# %%
df_clean = (
air_line
[['label','review']]
# convert to lower case
.assign(clean_document= lambda x: x.review.str.lower())
# remove punctuation : first way
.assign(clean_document= lambda x: x.clean_document.str.replace(r"[^\w\s]","",regex=True))
# remove numbers: second way, with compile
.assign(clean_document= lambda x: x.clean_document.str.replace(re.compile("\d"),"",regex=True))
# remove leading & trainling spaces 
.assign(clean_document = lambda x: x.clean_document.str.strip())
# remove all the '\n' values with space
.assign(clean_document= lambda x: x.clean_document.str.replace(re.compile(r"\n"),"",regex=True ))
# tokenize 
.assign(tokenized = lambda x: x.clean_document.str.split(" "))
# lastly, convert spam and ham into integers
.pipe(lambda x: ks.sql("select * , case when label = 'spam' then 1 else 0 end as label_coded from {x}"))
)
# Out:
# /databricks/spark/python/pyspark/sql/pandas/functions.py:386: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   warnings.warn(

# %%
df_clean.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#       <th>review</th>
#       <th>clean_document</th>
#       <th>tokenized</th>
#       <th>label_coded</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ham</td>
#       <td>Go until jurong point, crazy.. Available only ...</td>
#       <td>go until jurong point crazy available only in ...</td>
#       <td>[go, until, jurong, point, crazy, available, o...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ham</td>
#       <td>Ok lar... Joking wif u oni...</td>
#       <td>ok lar joking wif u oni</td>
#       <td>[ok, lar, joking, wif, u, oni]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>spam</td>
#       <td>Free entry in 2 a wkly comp to win FA Cup fina...</td>
#       <td>free entry in  a wkly comp to win fa cup final...</td>
#       <td>[free, entry, in, , a, wkly, comp, to, win, fa...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ham</td>
#       <td>U dun say so early hor... U c already then say...</td>
#       <td>u dun say so early hor u c already then say</td>
#       <td>[u, dun, say, so, early, hor, u, c, already, t...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ham</td>
#       <td>Nah I don't think he goes to usf, he lives aro...</td>
#       <td>nah i dont think he goes to usf he lives aroun...</td>
#       <td>[nah, i, dont, think, he, goes, to, usf, he, l...</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Apply Stop Words

# %%
# to remove stopword , we need to come back to spark dataframe
spark_df = df_clean.to_spark()

# %%
spark_df.show()
# Out:
# +-----+--------------------+--------------------+--------------------+-----------+
# |label|              review|      clean_document|           tokenized|label_coded|
# +-----+--------------------+--------------------+--------------------+-----------+
# |  ham|Go until jurong p...|go until jurong p...|[go, until, juron...|          0|
# |  ham|Ok lar... Joking ...|ok lar joking wif...|[ok, lar, joking,...|          0|
# | spam|Free entry in 2 a...|free entry in  a ...|[free, entry, in,...|          1|
# |  ham|U dun say so earl...|u dun say so earl...|[u, dun, say, so,...|          0|
# |  ham|Nah I don't think...|nah i dont think ...|[nah, i, dont, th...|          0|
# | spam|FreeMsg Hey there...|freemsg hey there...|[freemsg, hey, th...|          1|
# |  ham|Even my brother i...|even my brother i...|[even, my, brothe...|          0|
# |  ham|As per your reque...|as per your reque...|[as, per, your, r...|          0|
# | spam|WINNER!! As a val...|winner as a value...|[winner, as, a, v...|          1|
# | spam|Had your mobile 1...|had your mobile  ...|[had, your, mobil...|          1|
# |  ham|I'm gonna be home...|im gonna be home ...|[im, gonna, be, h...|          0|
# | spam|SIX chances to wi...|six chances to wi...|[six, chances, to...|          1|
# | spam|URGENT! You have ...|urgent you have w...|[urgent, you, hav...|          1|
# |  ham|I've been searchi...|ive been searchin...|[ive, been, searc...|          0|
# |  ham|I HAVE A DATE ON ...|i have a date on ...|[i, have, a, date...|          0|
# | spam|XXXMobileMovieClu...|xxxmobilemovieclu...|[xxxmobilemoviecl...|          1|
# |  ham|Oh k...i'm watchi...|oh kim watching here|[oh, kim, watchin...|          0|
# |  ham|Eh u remember how...|eh u remember how...|[eh, u, remember,...|          0|
# |  ham|Fine if that�s th...|fine if thats the...|[fine, if, thats,...|          0|
# | spam|England v Macedon...|england v macedon...|[england, v, mace...|          1|
# +-----+--------------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import StopWordsRemover
from pyspark.ml.feature import NGram

# %%
# Instantiate stop words 
stop = StopWordsRemover(inputCols=['tokenized'],outputCols=['SW_removed'])
# Instantiate ngram 
ngr = NGram(n=2,inputCol='SW_removed',outputCol='ngrammed',)

# %% [markdown]
# # Apply tf-idf

# %%
# lets get the verctor assambler
from pyspark.ml.feature import CountVectorizer
from pyspark.ml.feature import IDF

# %%
# instantiate the tf-idf
tf = CountVectorizer(inputCol='ngrammed',outputCol='tf_column')
idf = IDF(inputCol='tf_column',outputCol='tf_idf')

# %% [markdown]
# # Get the Vector Assembler

# %%
# vector assembler is the last building block for the feature transformation
from pyspark.ml.feature import VectorAssembler
Vec_assembler = VectorAssembler(inputCols=['tf_idf',],outputCol='features')

# %% [markdown]
# # Build the pipeline

# %%
from pyspark.ml import Pipeline

# %%
# apply the pipe, learn from the data (.fit) and then transform the data
pipe = Pipeline(stages=[stop,ngr,tf,idf,Vec_assembler])
fitted_pipe =  pipe.fit(spark_df)
transformed_data = fitted_pipe.transform(spark_df)

# %%
transformed_data.show()
# Out:
# +-----+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |label|              review|      clean_document|           tokenized|label_coded|          SW_removed|            ngrammed|           tf_column|              tf_idf|            features|
# +-----+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+
#
# |  ham|Eh u remember how...|eh u remember how...|[eh, u, remember,...|          0|[eh, u, remember,...|[eh u, u remember...|(31876,[3657,4335...|(31876,[3657,4335...|(31876,[3657,4335...|
# |  ham|Fine if that�s th...|fine if thats the...|[fine, if, thats,...|          0|[fine, thats, way...|[fine thats, that...|(31876,[225,591,1...|(31876,[225,591,1...|(31876,[225,591,1...|
# | spam|England v Macedon...|england v macedon...|[england, v, mace...|          1|[england, v, mace...|[england v, v mac...|(31876,[72,182,87...|(31876,[72,182,87...|(31876,[72,182,87...|
# +-----+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Apply the modeling

# %%
from pyspark.ml.classification import LogisticRegression

# %%
# start the model
lr = LogisticRegression(featuresCol='features',labelCol='label_coded')

# %%
# train the model
fitted_model = lr.fit(transformed_data)

# %%
# predict the model
prediction = fitted_model.transform(transformed_data)

# %%
prediction.show()
# Out:
# +-----+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |label|              review|      clean_document|           tokenized|label_coded|          SW_removed|            ngrammed|           tf_column|              tf_idf|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |  ham|Go until jurong p...|go until jurong p...|[go, until, juron...|          0|[go, jurong, poin...|[go jurong, juron...|(31876,[7332,1279...|(31876,[7332,1279...|(31876,[7332,1279...|[24.5231203318958...|[0.99999999997762...|       0.0|
# |  ham|Ok lar... Joking ...|ok lar joking wif...|[ok, lar, joking,...|          0|[ok, lar, joking,...|[ok lar, lar joki...|(31876,[1435,4419...|(31876,[1435,4419...|(31876,[1435,4419...|[62.5487342948979...|           [1.0,0.0]|       0.0|
# | spam|Free entry in 2 a...|free entry in  a ...|[free, entry, in,...|          1|[free, entry, , w...|[free entry, entr...|(31876,[55,86,99,...|(31876,[55,86,99,...|(31876,[55,86,99,...|[-309.19682707618...|[5.21824155357460...|       1.0|
# |  ham|U dun say so earl...|u dun say so earl...|[u, dun, say, so,...|          0|[u, dun, say, ear...|[u dun, dun say, ...|(31876,[147,230,5...|(31876,[147,230,5...|(31876,[147,230,5...|[64.9401598453329...|           [1.0,0.0]|       0.0|
# |  ham|Nah I don't think...|nah i dont think ...|[nah, i, dont, th...|          0|[nah, dont, think...|[nah dont, dont t...|(31876,[139,6890,...|(31876,[139,6890,...|(31876,[139,6890,...|[71.6068156879083...|           [1.0,0.0]|       0.0|
# | spam|FreeMsg Hey there...|freemsg hey there...|[freemsg, hey, th...|          1|[freemsg, hey, da...|[freemsg hey, hey...|(31876,[314,564,1...|(31876,[314,564,1...|(31876,[314,564,1...|[-198.65435915260...|[5.31505807245600...|       1.0|
# |  ham|Even my brother i...|even my brother i...|[even, my, brothe...|          0|[even, brother, l...|[even brother, br...|(31876,[7959,8060...|(31876,[7959,8060...|(31876,[7959,8060...|[72.7890072565998...|           [1.0,0.0]|       0.0|
# |  ham|As per your reque...|as per your reque...|[as, per, your, r...|          0|[per, request, me...|[per request, req...|(31876,[210,533,6...|(31876,[210,533,6...|(31876,[210,533,6...|[45.9355933469555...|           [1.0,0.0]|       0.0|
# | spam|WINNER!! As a val...|winner as a value...|[winner, as, a, v...|          1|[winner, valued, ...|[winner valued, v...|(31876,[2,5,13,76...|(31876,[2,5,13,76...|(31876,[2,5,13,76...|[-265.69012601084...|[4.09491015326122...|       1.0|
# | spam|Had your mobile 1...|had your mobile  ...|[had, your, mobil...|          1|[mobile, , months...|[mobile ,  months...|(31876,[11,35,69,...|(31876,[11,35,69,...|(31876,[11,35,69,...|[-182.23618045280...|[7.17517381701716...|       1.0|
# |  ham|I'm gonna be home...|im gonna be home ...|[im, gonna, be, h...|          0|[im, gonna, home,...|[im gonna, gonna ...|(31876,[58,164,10...|(31876,[58,164,10...|(31876,[58,164,10...|[39.7265310030489...|           [1.0,0.0]|       0.0|
# | spam|SIX chances to wi...|six chances to wi...|[six, chances, to...|          1|[six, chances, wi...|[six chances, cha...|(31876,[0,28,108,...|(31876,[0,28,108,...|(31876,[0,28,108,...|[-254.97185693162...|[1.84982009925610...|       1.0|
# | spam|URGENT! You have ...|urgent you have w...|[urgent, you, hav...|          1|[urgent, won, , w...|[urgent won, won ...|(31876,[5,12,63,1...|(31876,[5,12,63,1...|(31876,[5,12,63,1...|[-248.01919086249...|[1.93479074953137...|       1.0|
# |  ham|I've been searchi...|ive been searchin...|[ive, been, searc...|          0|[ive, searching, ...|[ive searching, s...|(31876,[7108,1014...|(31876,[7108,1014...|(31876,[7108,1014...|[24.5231203318958...|[0.99999999997762...|       0.0|
# |  ham|I HAVE A DATE ON ...|i have a date on ...|[i, have, a, date...|          0|      [date, sunday]|       [date sunday]|(31876,[17440],[1...|(31876,[17440],[7...|(31876,[17440],[7...|[42.1995570784486...|           [1.0,0.0]|       0.0|
# | spam|XXXMobileMovieClu...|xxxmobilemovieclu...|[xxxmobilemoviecl...|          1|[xxxmobilemoviecl...|[xxxmobilemoviecl...|(31876,[11072,123...|(31876,[11072,123...|(31876,[11072,123...|[-189.02756789064...|[8.06065507361968...|       1.0|
# |  ham|Oh k...i'm watchi...|oh kim watching here|[oh, kim, watchin...|          0| [oh, kim, watching]|[oh kim, kim watc...|(31876,[15145,267...|(31876,[15145,267...|(31876,[15145,267...|[50.5392711393341...|           [1.0,0.0]|       0.0|
# |  ham|Eh u remember how...|eh u remember how...|[eh, u, remember,...|          0|[eh, u, remember,...|[eh u, u remember...|(31876,[3657,4335...|(31876,[3657,4335...|(31876,[3657,4335...|[72.0006047179192...|           [1.0,0.0]|       0.0|
# |  ham|Fine if that�s th...|fine if thats the...|[fine, if, thats,...|          0|[fine, thats, way...|[fine thats, that...|(31876,[225,591,1...|(31876,[225,591,1...|(31876,[225,591,1...|[69.7017363389921...|           [1.0,0.0]|       0.0|
# | spam|England v Macedon...|england v macedon...|[england, v, mace...|          1|[england, v, mace...|[england v, v mac...|(31876,[72,182,87...|(31876,[72,182,87...|(31876,[72,182,87...|[-250.89168331692...|[1.09427475476813...|       1.0|
# +-----+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %% [markdown]
# # Evaluate your model

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
# instantiate evaluator
mc = MulticlassClassificationEvaluator(labelCol='label_coded',metricName='weightedRecall',)

# %%
# run the evaluator
mc.evaluate(prediction)
# Out:
# Out[32]: 0.9996411912450665

# %% [markdown]
# # you can put everything togather in the pipeline

# %%
pipe = Pipeline(stages=[stop,ngr,tf,idf,Vec_assembler,lr])
fitted_pipe =  pipe.fit(spark_df)
transformed_data = fitted_pipe.transform(spark_df)

# %%
# you can now evaluate on transformed data !!!!!
